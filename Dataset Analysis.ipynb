# %%
import numpy as np
import pandas as pd
import json

# %%
with open("Datasets/fewrel_train_wiki.json") as file:
    train = json.load(file)

with open("Datasets/fewrel_val_wiki.json") as file:
    val = json.load(file)

# %%
len(train.keys()), len(val.keys()), train.keys()
# Out:
# (64,
#  16,
#  dict_keys(['P931', 'P4552', 'P140', 'P1923', 'P150', 'P6', 'P27', 'P449', 'P1435', 'P175', 'P1344', 'P39', 'P527', 'P740', 'P706', 'P84', 'P495', 'P123', 'P57', 'P22', 'P178', 'P241', 'P403', 'P1411', 'P135', 'P991', 'P156', 'P176', 'P31', 'P1877', 'P102', 'P1408', 'P159', 'P3373', 'P1303', 'P17', 'P106', 'P551', 'P937', 'P355', 'P710', 'P137', 'P674', 'P466', 'P136', 'P306', 'P127', 'P400', 'P974', 'P1346', 'P460', 'P86', 'P118', 'P264', 'P750', 'P58', 'P3450', 'P105', 'P276', 'P101', 'P407', 'P1001', 'P800', 'P131']))

# %%
train['P931'][:2]
# Out:
# [{'tokens': ['Merpati',
#    'flight',
#    '106',
#    'departed',
#    'Jakarta',
#    '(',
#    'CGK',
#    ')',
#    'on',
#    'a',
#    'domestic',
#    'flight',
#    'to',
#    'Tanjung',
#    'Pandan',
#    '(',
#    'TJQ',
#    ')',
#    '.'],
#   'h': ['tjq', 'Q1331049', [[16]]],
#   't': ['tanjung pandan', 'Q3056359', [[13, 14]]]},
#  {'tokens': ['The',
#    'name',
#    'was',
#    'at',
#    'one',
#    'point',
#    'changed',
#    'to',
#    'Nottingham',
#    'East',
#    'Midlands',
#    'Airport',
#    'so',
#    'as',
#    'to',
#    'include',
#    'the',
#    'name',
#    'of',
#    'the',
#    'city',
#    'that',
#    'is',
#    'supposedly',
#    'most',
#    'internationally',
#    'recognisable',
#    ',',
#    'mainly',
#    'due',
#    'to',
#    'the',
#    'Robin',
#    'Hood',
#    'legend',
#    '.'],
#   'h': ['east midlands airport', 'Q8977', [[9, 10, 11]]],
#   't': ['nottingham', 'Q41262', [[8]]]}]

# %% [markdown]
# We can see the general structure, the first level of the JSON represents a relation type, and contains all the sample of that relation
#
# Each relation sample contains the tokenised sentence, head and tail entity (which each contain some unknown numbers)

# %%
sentence_lengths = {}
for key, samples in train.items():
    sentence_lengths[key] = []
    for s in samples:
        sentence_lengths[key].append(len(s['tokens']))
    sentence_lengths[key] = np.mean(sentence_lengths[key])

print("Overall mean sentence length:", np.mean(list(sentence_lengths.values())))
print("Mean sentence length per class:")
sentence_lengths
# Out:
# Overall mean sentence length: 24.98064732142857
# Mean sentence length per class:
# {'P931': 23.091428571428573,
#  'P4552': 25.942857142857143,
#  'P140': 25.415714285714287,
#  'P1923': 25.077142857142857,
#  'P150': 22.97,
#  'P6': 25.041428571428572,
#  'P27': 25.04,
#  'P449': 25.041428571428572,
#  'P1435': 22.568571428571428,
#  'P175': 25.945714285714285,
#  'P1344': 26.275714285714287,
#  'P39': 25.315714285714286,
#  'P527': 25.798571428571428,
#  'P740': 23.074285714285715,
#  'P706': 24.07857142857143,
#  'P84': 25.964285714285715,
#  'P495': 24.662857142857142,
#  'P123': 25.6,
#  'P57': 25.018571428571427,
#  'P22': 25.745714285714286,
#  'P178': 25.055714285714284,
#  'P241': 25.382857142857144,
#  'P403': 23.23857142857143,
#  'P1411': 27.17142857142857,
#  'P135': 26.195714285714285,
#  'P991': 25.277142857142856,
#  'P156': 26.924285714285713,
#  'P176': 25.262857142857143,
#  'P31': 24.93285714285714,
#  'P1877': 25.982857142857142,
#  'P102': 25.035714285714285,
#  'P1408': 24.717142857142857,
#  'P159': 24.478571428571428,
#  'P3373': 25.635714285714286,
#  'P1303': 24.19857142857143,
#  'P17': 25.595714285714287,
#  'P106': 21.664285714285715,
#  'P551': 24.80857142857143,
#  'P937': 25.611428571428572,
#  'P355': 25.077142857142857,
#  'P710': 25.782857142857143,
#  'P137': 25.44142857142857,
#  'P674': 26.99142857142857,
#  'P466': 25.42,
#  'P136': 23.94,
#  'P306': 24.02285714285714,
#  'P127': 25.33,
#  'P400': 26.18857142857143,
#  'P974': 22.338571428571427,
#  'P1346': 25.437142857142856,
#  'P460': 24.035714285714285,
#  'P86': 26.42142857142857,
#  'P118': 25.082857142857144,
#  'P264': 25.552857142857142,
#  'P750': 26.018571428571427,
#  'P58': 25.69142857142857,
#  'P3450': 24.50857142857143,
#  'P105': 20.46142857142857,
#  'P276': 25.28142857142857,
#  'P101': 24.702857142857145,
#  'P407': 24.282857142857143,
#  'P1001': 25.217142857142857,
#  'P800': 25.672857142857143,
#  'P131': 25.02285714285714}

# %%
# Examine what the numbers in entity entries mean
heads = []
for key, samples in train.items():
    for s in samples:
        heads.extend([s['h'], s['t']])

# %%
heads
# Out:
# [['tjq', 'Q1331049', [[16]]],
#  ['tanjung pandan', 'Q3056359', [[13, 14]]],
#  ['east midlands airport', 'Q8977', [[9, 10, 11]]],
#  ['nottingham', 'Q41262', [[8]]],
#  ['fort lauderdale-hollywood international airport',
#   'Q635361',
#   [[9, 10, 11, 12, 13, 14]]],
#  ['fort lauderdale, florida', 'Q165972', [[16, 17, 18, 19]]],
#  ['jinnah international airport', 'Q61052', [[6, 7, 8]]],
#  ['karachi', 'Q8660', [[10]]],
#  ['margaret ekpo international airport', 'Q1030578', [[9, 10, 11, 12]]],
#  ['calabar', 'Q844091', [[14]]],
#  ['pakyong airport', 'Q7126092', [[0, 1]]],
#  ['gangtok', 'Q186141', [[12]]],
#  ['tinson pen aerodrome', 'Q2320308', [[3, 4, 5]]],
#  ['kingston', 'Q34692', [[7]]],
#  ['noumérat – moufdi zakaria airport', 'Q1432199', [[9, 10, 11, 12, 13]]],
#  ['ghardaïa', 'Q622841', [[15]]],
#  ['kazi nazrul islam airport', 'Q14941562', [[7, 8, 9, 10]]],
#  ['durgapur', 'Q5088', [[12]]],
#  ['robin hood airport', 'Q8996', [[4, 5, 6]]],
#  ['doncaster', 'Q58900', [[8]]],
#  ['large regional airport', 'Q180129', [[3, 4, 5]]],
#  ['manchester', 'Q48370', [[0]]],
#  ['airport', 'Q7199486', [[30]]],
#  ['pittsfield', 'Q49184', [[9], [28]]],
#  ['alberto delgado airport', 'Q4711997', [[27, 28, 29]]],
#  ['trinidad', 'Q319272', [[15]]],
#  ['ferenc liszt international airport', 'Q500945', [[10, 11, 12, 13]]],
#  ['budapest', 'Q1781', [[15]]],
#  ['menominee-marinette twin county airport',
#   'Q27308800',
#   [[5, 6, 7, 8, 9, 10]]],
#  ['menominee, michigan', 'Q2635319', [[12, 13, 14]]],
#  ['bacha khan international airport', 'Q1516769', [[2, 3, 4, 5]]],
#  ['peshawar', 'Q1113311', [[0]]],
#  ['sultan aji muhammad sulaiman airport', 'Q263652', [[16, 17, 18, 19, 20]]],
#  ['balikpapan', 'Q14492', [[22]]],
#  ['presidente médici international airport', 'Q6587048', [[0, 1, 2, 3]]],
#  ['rio branco', 'Q171612', [[12, 13]]],
#  ['temple bar airport', 'Q6588459', [[14, 15, 16]]],
#  ['temple bar marina', 'Q7698447', [[0, 1, 2]]],
#  ['toledo express airport', 'Q6588637', [[6, 7, 8]]],
#  ['toledo, ohio', 'Q49239', [[10, 11, 12]]],
#  ['greenbrier valley airport', 'Q3914326', [[0, 1, 2]]],
#  ['lewisburg, west virginia', 'Q731071', [[12, 13, 14, 15]]],
#  ['international airport', 'Q1232348', [[1, 2], [17, 18]]],
#  ['chania', 'Q182299', [[4]]],
#  ['gurney airport', 'Q1069088', [[8, 9]]],
#  ['alotau', 'Q568137', [[11]]],
#  ['bangoka airport', 'Q27596', [[7, 8]]],
#  ['kisangani', 'Q146723', [[5]]],
#  ['borg el arab airport', 'Q1194015', [[7, 8, 9, 10]]],
#  ['alexandria', 'Q87', [[5]]],
#  ['rockwood municipal airport', 'Q10851312', [[10, 11, 12]]],
#  ['rockwood, tennessee', 'Q979056', [[5, 6, 7]]],
#  ['savannah/hilton head international airport',
#   'Q1432789',
#   [[5, 6, 7, 8, 9, 10]]],
#  ['savannah, georgia', 'Q83813', [[16, 17, 18]]],
#  ['juan santamaría international airport', 'Q555940', [[9, 10, 11, 12]]],
#  ['san josé', 'Q3070', [[14, 15]]],
#  ['djibouti–ambouli international airport', 'Q620706', [[1, 2, 3, 4, 5]]],
#  ['djibouti city', 'Q3604', [[14, 15]]],
#  ['magic valley regional airport', 'Q6730879', [[7, 8, 9, 10]]],
#  ['twin falls, idaho', 'Q548384', [[13, 14, 15, 16]]],
#  ['abernathy field', 'Q428353', [[0, 1]]],
#  ['city of pulaski', 'Q1410885', [[13, 14, 15]]],
#  ['tuscola area airport', 'Q7856724', [[21, 22, 23]]],
#  ['caro, michigan', 'Q14032', [[25, 26, 27]]],
#  ['raja bhoj airport', 'Q7285421', [[4, 5, 6]]],
#  ['bhopal', 'Q80989', [[7]]],
#  ['maya-maya airport', 'Q644963', [[5, 6, 7, 8]]],
#  ['brazzaville', 'Q3844', [[11]]],
#  ['tourane airfield', 'Q773330', [[25, 26]]],
#  ['da nang', 'Q25282', [[22, 23]]],
#  ['qamdo bamda airport', 'Q531800', [[12, 13, 14]]],
#  ['chamdo', 'Q1012419', [[16]]],
#  ['tingwall airport', 'Q2875973', [[6, 7]]],
#  ['shetland islands', 'Q47134', [[10, 11]]],
#  ['domestic airport', 'Q1595059', [[13, 14]]],
#  ['jamnagar', 'Q1154', [[7]]],
#  ['diori hamani international airport', 'Q905933', [[0, 1, 2, 3]]],
#  ['niamey', 'Q3674', [[8]]],
#  ['davenport municipal airport', 'Q1707887', [[10, 11, 12]]],
#  ['davenport, iowa', 'Q26887', [[14, 15, 16]]],
#  ['billings logan international airport', 'Q598269', [[10, 11, 12, 13]]],
#  ['billings, montana', 'Q166304', [[15, 16, 17]]],
#  ['modlin airport', 'Q1401995', [[2, 3]]],
#  ['warsaw', 'Q270', [[0]]],
#  ['tomás de heres airport', 'Q1931117', [[0, 1, 2, 3]]],
#  ['ciudad bolívar', 'Q26906', [[11, 12]]],
#  ['chicago rockford international airport', 'Q1071990', [[15, 16, 17, 18]]],
#  ['rockford, illinois', 'Q233892', [[21, 22, 23]]],
#  ['yolo county airport', 'Q10853689', [[0, 1, 2]]],
#  ['davis', 'Q668546', [[14]]],
#  ['newcastle airport', 'Q8975', [[4, 5]]],
#  ['tyne and wear', 'Q23080', [[7, 8, 9]]],
#  ['la tontouta international airport', 'Q892783', [[5, 6, 7, 8]]],
#  ['nouméa', 'Q9733', [[0]]],
#  ['zvartnots international airport', 'Q1124922', [[0, 1, 2]]],
#  ['yerevan', 'Q1953', [[4]]],
#  ['mohawk valley airport', 'Q3565424', [[0, 1, 2]]],
#  ['scotia', 'Q1020602', [[20]]],
#  ['sawyer international airport', 'Q4568758', [[4, 5, 6]]],
#  ['marquette', 'Q12443', [[2]]],
#  ['matari airport', 'Q652383', [[4, 5]]],
#  ['isiro', 'Q899873', [[0]]],
#  ['cartierville airport', 'Q1961318', [[24, 25]]],
#  ['saint-laurent', 'Q2117999', [[19, 20, 21]]],
#  ['rapid city regional airport', 'Q2876124', [[6, 7, 8, 9]]],
#  ['rapid city, south dakota', 'Q213325', [[11, 12, 13, 14, 15]]],
#  ['baiyun airport', 'Q44868', [[2, 3]]],
#  ['guangzhou', 'Q16572', [[5]]],
#  ['incheon international airport', 'Q20932', [[13, 14, 15]]],
#  ['seoul', 'Q8684', [[17]]],
#  ['césar gaviria trujillo airport', 'Q1323400', [[0, 1, 2, 3]]],
#  ['inírida', 'Q130281', [[11]]],
#  ['flabob airport', 'Q5456581', [[20, 21]]],
#  ['riverside, california', 'Q49243', [[23, 24, 25]]],
#  ['kbwi', 'Q94895', [[32]]],
#  ['baltimore, maryland', 'Q5092', [[28, 29, 30]]],
#  ['moi international airport', 'Q392784', [[4, 5, 6]]],
#  ['mombasa', 'Q225641', [[8]]],
#  ['leo wattimena airport', 'Q4272507', [[0, 1, 2]]],
#  ['morotai island', 'Q19146', [[19, 20]]],
#  ['jorge isaacs airport', 'Q2902722', [[5, 6, 7]]],
#  ['maicao', 'Q1937427', [[15]]],
#  ['buon ma thuot airport', 'Q695570', [[6, 7, 8, 9]]],
#  ['buôn ma thuột', 'Q33469', [[0, 1, 2]]],
#  ['jeju international airport', 'Q482497', [[26, 27, 28]]],
#  ['jeju island', 'Q29151', [[7, 8]]],
#  ['childress municipal airport', 'Q3274003', [[0, 1, 2]]],
#  ['childress, texas', 'Q982513', [[17, 18, 19]]],
#  ['josé leonardo chirino airport', 'Q1322397', [[0, 1, 2, 3]]],
#  ['coro', 'Q1134454', [[9]]],
#  ['reading regional airport', 'Q7300558', [[19, 20, 21]]],
#  ['reading, pennsylvania', 'Q237896', [[23, 24, 25]]],
#  ['stansted', 'Q8709', [[8]]],
#  ['london', 'Q84', [[6]]],
#  ['bob adams field', 'Q7605416', [[4, 5, 6]]],
#  ['steamboat springs', 'Q984721', [[0, 1], [17, 18]]],
#  ['bullfrog basin airport', 'Q3887489', [[0, 1, 2]]],
#  ['glen canyon national recreation area', 'Q1373278', [[16, 17, 18, 19, 20]]],
#  ['las breas airport', 'Q16893977', [[0, 1, 2]]],
#  ['taltal', 'Q188049', [[13]]],
#  ['sri sathya sai airport', 'Q1939560', [[13, 14, 15, 16]]],
#  ['puttaparthi', 'Q1068595', [[9]]],
#  ['boryspil international airport', 'Q477677', [[5, 6, 7]]],
#  ['kyiv', 'Q1899', [[24]]],
#  ['alxa left banner bayanhot airport', 'Q16258986', [[20, 21, 22, 23, 24]]],
#  ['alxa league', 'Q449963', [[9, 10]]],
#  ['capital city airport', 'Q3274856', [[0, 1, 2]]],
#  ['harrisburg', 'Q25280', [[11]]],
#  ['meythet airport', 'Q1430810', [[0, 1]]],
#  ['annecy', 'Q50189', [[3]]],
#  ['sheppard air force base', 'Q176146', [[25, 26, 27, 28]]],
#  ['wichita falls', 'Q128349', [[21, 22]]],
#  ['abraham lincoln capital airport', 'Q1320523', [[12, 13, 14, 15]]],
#  ['springfield', 'Q28515', [[17]]],
#  ['essendon', 'Q1319272', [[19]]],
#  ['melbourne', 'Q3141', [[21]]],
#  ['laurel municipal airport', 'Q6499928', [[1, 2, 3]]],
#  ['laurel, montana', 'Q768628', [[13, 14, 15]]],
#  ['hualien airport', 'Q703921', [[5, 6]]],
#  ['hualien city', 'Q713310', [[0, 1]]],
#  ['rafael hernández international airport', 'Q2276582', [[10, 11, 12, 13]]],
#  ['aguadilla, puerto rico', 'Q397826', [[15, 16, 17, 18]]],
#  ['al dhafra air base', 'Q2886453', [[21, 22, 23, 24]]],
#  ['abu dhabi', 'Q1519', [[26, 27]]],
#  ['johan pienaar airport', 'Q1580098', [[0, 1, 2]]],
#  ['kuruman', 'Q1025965', [[7]]],
#  ['shah amanat international airport', 'Q525609', [[20, 21, 22, 23]]],
#  ['chittagong', 'Q376749', [[25]]],
#  ['northwest missouri regional airport', 'Q7060119', [[5, 6, 7, 8]]],
#  ['maryville', 'Q957284', [[10]]],
#  ['portsmouth international airport at pease',
#   'Q6587102',
#   [[12, 13, 14, 15, 16]]],
#  ['portsmouth, new hampshire', 'Q49191', [[18, 19, 20, 21]]],
#  ['tribhuvan international airport', 'Q61066', [[22, 23, 24]]],
#  ['kathmandu', 'Q3037', [[18]]],
#  ['albert whitted airport', 'Q4711466', [[13, 14, 15]]],
#  ['st petersburg', 'Q49236', [[17, 18]]],
#  ['mammoth yosemite airport', 'Q6745883', [[0, 1, 2]]],
#  ['mammoth lakes', 'Q983604', [[14, 15]]],
#  ['mayor galo de la torre airport', 'Q22632230', [[4, 5, 6, 7, 8, 9]]],
#  ['tena', 'Q994312', [[2]]],
#  ['san luis valley regional airport', 'Q7414773', [[4, 5, 6, 7, 8]]],
#  ['alamosa', 'Q1010247', [[0]]],
#  ['dallas-fort worth international airport',
#   'Q459096',
#   [[11, 12, 13, 14, 15, 16]]],
#  ['dallas-fort worth metroplex', 'Q179295', [[1, 2, 3, 4, 5]]],
#  ['bassillac airport', 'Q1432520', [[2, 3]]],
#  ['périgueux', 'Q6588', [[0]]],
#  ['airstrip', 'Q7455033', [[23]]],
#  ['seronera', 'Q6273481', [[4]]],
#  ['bathpalathang airport', 'Q153191', [[6, 7]]],
#  ['jakar', 'Q2468415', [[0]]],
#  ['"skid strip"', 'Q3275436', [[14, 15, 16, 17]]],
#  ['cape canaveral air force station', 'Q334465', [[4, 5, 6, 7, 8]]],
#  ['siglufjordur airport', 'Q2875922', [[3, 4]]],
#  ['siglufjörður', 'Q1887662', [[0], [9]]],
#  ['randolph field', 'Q980034', [[10, 11]]],
#  ['san antonio', 'Q975', [[13, 14]]],
#  ['phoenix-mesa gateway airport', 'Q493759', [[5, 6, 7, 8, 9]]],
#  ['mesa, arizona', 'Q49261', [[14, 15, 16]]],
#  ['golosón international airport', 'Q2231517', [[4, 5, 6]]],
#  ['la ceiba', 'Q916536', [[8, 9]]],
#  ['john bell williams airport', 'Q2901886', [[20, 21, 22, 23]]],
#  ['raymond, mississippi', 'Q1779125', [[8, 9, 10]]],
#  ['begumpet airport', 'Q1657769', [[7, 8]]],
#  ['hyderabad', 'Q1361', [[10]]],
#  ['visalia municipal airport', 'Q7935607', [[1, 2, 3]]],
#  ['visalia, california', 'Q495373', [[14, 15, 16]]],
#  ['stinson field municipal airport', 'Q7617473', [[0, 1, 2, 3]]],
#  ['aberdeen, mississippi', 'Q1065452', [[12, 13, 14]]],
#  ['sua pan airport', 'Q7630421', [[0, 1, 2]]],
#  ['sowa', 'Q141310', [[4], [11]]],
#  ['momona airport', 'Q1364375', [[9, 10]]],
#  ['dunedin', 'Q133073', [[6]]],
#  ['bob sikes airport', 'Q597487', [[8, 9, 10]]],
#  ['crestview, florida', 'Q2153124', [[12, 13, 14]]],
#  ['rnzaf base ohakea', 'Q7277291', [[15, 16, 17]]],
#  ['palmerston north', 'Q212289', [[19, 20]]],
#  ['camp mcgovern', 'Q16890056', [[20, 21]]],
#  ['brčko', 'Q322828', [[0]]],
#  ['greater cumberland regional airport', 'Q3913914', [[12, 13, 14, 15]]],
#  ['cumberland, maryland', 'Q754868', [[21, 22, 23]]],
#  ['cakung airport', 'Q1430948', [[4, 5]]],
#  ['baucau', 'Q811130', [[0], [14]]],
#  ['borrego valley airport', 'Q3606044', [[15, 16, 17]]],
#  ['borrego springs, california', 'Q2049424', [[9, 10, 11, 12]]],
#  ['maria cristina airport', 'Q1031517', [[0, 1, 2]]],
#  ['iligan', 'Q285488', [[21]]],
#  ['eros airport', 'Q1321635', [[29, 30]]],
#  ['windhoek', 'Q3935', [[27]]],
#  ['camp speicher', 'Q5013269', [[19, 20]]],
#  ['tikrit', 'Q165444', [[22]]],
#  ['curtis field', 'Q1656327', [[17, 18]]],
#  ['brady, texas', 'Q981872', [[7, 8, 9]]],
#  ['airports', 'Q937590', [[12]]],
#  ['long island', 'Q18438', [[6, 7]]],
#  ['jean airport', 'Q2901394', [[17, 18]]],
#  ['jean, nevada', 'Q3709757', [[20, 21, 22]]],
#  ['piarco international airport', 'Q788810', [[16, 17, 18]]],
#  ['port of spain', 'Q39178', [[9, 10, 11], [26, 27, 28]]],
#  ['cherry capital airport', 'Q1433080', [[11, 12, 13]]],
#  ['traverse city', 'Q984544', [[15, 16]]],
#  ['oxnard airport', 'Q7115707', [[13, 14]]],
#  ['oxnard, california', 'Q209338', [[22, 23, 24]]],
#  ['jay prakash narayan international airport',
#   'Q2673010',
#   [[28, 29, 30, 31, 32]]],
#  ['patna', 'Q80484', [[34]]],
#  ['pnq', 'Q1432525', [[6]]],
#  ['pune', 'Q1538', [[0], [20]]],
#  ['bartolomeu de gusmão airport', 'Q4784257', [[10, 11, 12, 13]]],
#  ['araraquara', 'Q626247', [[5]]],
#  ['phu bai international airport', 'Q160094', [[0, 1, 2, 3]]],
#  ['huế', 'Q36167', [[22]]],
#  ['taipei songshan airport', 'Q702019', [[11, 12, 13]]],
#  ['taipei city', 'Q1867', [[8, 9]]],
#  ['liberal mid-america regional airport',
#   'Q6540690',
#   [[18, 19, 20, 21, 22, 23]]],
#  ['liberal, kansas', 'Q1003630', [[12, 13, 14]]],
#  ['kdlh', 'Q3277758', [[5]]],
#  ['duluth', 'Q485708', [[8]]],
#  ['sri guru ram dass jee international airport',
#   'Q385356',
#   [[12, 13, 14, 15, 16, 17, 18]]],
#  ['amritsar', 'Q48403', [[25]]],
#  ['kilimanjaro international airport', 'Q1365099', [[15, 16, 17]]],
#  ['arusha', 'Q4301', [[2]]],
#  ['governor francisco gabrielli international airport',
#   'Q1432029',
#   [[19, 20, 21, 22, 23]]],
#  ['mendoza', 'Q44237', [[25]]],
#  ['heathrow', 'Q8691', [[14]]],
#  ['london', 'Q84', [[1]]],
#  ['blue grass airport', 'Q598259', [[19, 20, 21]]],
#  ['lexington, kentucky', 'Q49241', [[23, 24, 25]]],
#  ['baikal international airport', 'Q2719346', [[11, 12, 13]]],
#  ['ulan-ude', 'Q6816', [[15, 16, 17]]],
#  ['kbely airport', 'Q1935013', [[0, 1]]],
#  ['prague', 'Q1085', [[8]]],
#  ['enyu airfield', 'Q598311', [[7, 8]]],
#  ['bikini atoll', 'Q152225', [[0, 1], [18, 19]]],
#  ['olaya herrera airport', 'Q1431257', [[27, 28, 29]]],
#  ['medellín', 'Q48278', [[31]]],
#  ['littlefield municipal airport', 'Q6652959', [[0, 1, 2]]],
#  ['littlefield, texas', 'Q202736', [[24, 25, 26]]],
#  ['capitán germán quiroga guardia airport', 'Q2875720', [[0, 1, 2, 3, 4]]],
#  ['san borja', 'Q2307472', [[9, 10]]],
#  ['moses point airport', 'Q3886700', [[0, 1, 2]]],
#  ['elim', 'Q79557', [[8]]],
#  ['huatugou airport', 'Q3207552', [[13, 14]]],
#  ['mangnai', 'Q1201941', [[18]]],
#  ['kulyab airport', 'Q2231909', [[3, 4]]],
#  ['kulob', 'Q132043', [[0], [9]]],
#  ['own airport', 'Q1175431', [[27, 28]]],
#  ['gold coast', 'Q140075', [[4, 5], [24, 25]]],
#  ['ernesto cortissoz international airport', 'Q645151', [[20, 21, 22, 23]]],
#  ['barranquilla', 'Q62823', [[8]]],
#  ['huntsville international airport', 'Q2213419', [[20, 21, 22]]],
#  ['huntsville, alabama', 'Q79860', [[15, 16, 17]]],
#  ['maota airport', 'Q1030546', [[0, 1]]],
#  ['salelologa', 'Q2214151', [[15]]],
#  ['kertajati international airport', 'Q889070', [[20, 21, 22]]],
#  ['west java', 'Q3724', [[4, 5]]],
#  ['sonari airport', 'Q7560814', [[8, 9]]],
#  ['jamshedpur', 'Q200054', [[11]]],
#  ['an international airport', 'Q6587028', [[2, 3, 4]]],
#  ['parnaíba', 'Q1643864', [[0]]],
#  ['international airport', 'Q570873', [[12, 13]]],
#  ['damascus', 'Q3766', [[10]]],
#  ['tobías bolaños international airport', 'Q3500191', [[3, 4, 5, 6]]],
#  ['san josé', 'Q3070', [[8, 9]]],
#  ['luis muñoz marín international airport', 'Q1360523', [[7, 8, 9, 10, 11]]],
#  ['san juan', 'Q41211', [[13, 14]]],
#  ['general mariano escobedo international airport',
#   'Q767660',
#   [[9, 10, 11, 12, 13]]],
#  ['monterrey', 'Q81033', [[0]]],
#  ['msalato international airport', 'Q16895494', [[0, 1, 2]]],
#  ['dodoma', 'Q3866', [[17]]],
#  ['bogashevo airport', 'Q1322435', [[17, 18]]],
#  ['tomsk', 'Q976', [[20]]],
#  ['pedro juan caballero airport', 'Q1657937', [[5, 6, 7, 8]]],
#  ['pedro juan caballero, paraguay', 'Q849292', [[10, 11, 12, 13, 14]]],
#  ['jomo kenyatta international airport', 'Q206349', [[9, 10, 11, 12]]],
#  ['nairobi', 'Q3870', [[14]]],
#  ['international airport', 'Q2308399', [[14, 15]]],
#  ['san pedro sula', 'Q274584', [[1, 2, 3]]],
#  ['lee bird field', 'Q7056358', [[6, 7, 8]]],
#  ['north platte, nebraska', 'Q989960', [[11, 12, 13, 14]]],
#  ['rafael núñez international airport', 'Q2670003', [[22, 23, 24, 25]]],
#  ['cartagena', 'Q657461', [[13]]],
#  ['newnam field', 'Q5330836', [[13, 14], [20, 21]]],
#  ['easton', 'Q754306', [[11], [18]]],
#  ['teterboro airport', 'Q1433053', [[8, 9]]],
#  ['teterboro, new jersey', 'Q936782', [[11, 12, 13, 14]]],
#  ['juan enrique airport', 'Q16896327', [[0, 1, 2]]],
#  ['paine', 'Q51070', [[11]]],
#  ['wynyard airport', 'Q15540', [[6, 7], [9, 10]]],
#  ['burnie', 'Q175262', [[0], [5], [27]]],
#  ['rinas international airport', 'Q217226', [[10, 11, 12]]],
#  ['tirana', 'Q19689', [[0]]],
#  ['rach gia airport', 'Q1993204', [[2, 3, 4]]],
#  ['rạch giá', 'Q36093', [[10, 11]]],
#  ['kotoka international airport', 'Q177689', [[16, 17, 18]]],
#  ['accra', 'Q3761', [[19]]],
#  ['vomd', 'Q3465662', [[10]]],
#  ['madurai', 'Q228405', [[0], [17]]],
#  ['ford airport', 'Q5467650', [[4, 5]]],
#  ['iron mountain, michigan', 'Q567814', [[7, 8, 9, 10]]],
#  ['biard airport', 'Q1432405', [[9, 10]]],
#  ['poitiers', 'Q6616', [[5], [7]]],
#  ['calhoun county airport', 'Q3813482', [[0, 1, 2]]],
#  ['port lavaca', 'Q982477', [[17, 18]]],
#  ['governador aluizio alves international airport',
#   'Q2090101',
#   [[0, 1, 2, 3, 4]]],
#  ['natal', 'Q131620', [[15]]],
#  ['ordos ejin horo airport', 'Q3538450', [[0, 1, 2, 3]]],
#  ['ordos city', 'Q570937', [[8, 9]]],
#  ['tingoa airport', 'Q3436133', [[2, 3]]],
#  ['tigoa', 'Q987011', [[8]]],
#  ['raaf williams', 'Q1551483', [[12, 13]]],
#  ['melbourne', 'Q3141', [[15]]],
#  ['el loa airport', 'Q3299637', [[20, 21, 22]]],
#  ['calama', 'Q3685', [[24]]],
#  ['valkaria airport', 'Q7911753', [[24, 25]]],
#  ['grant-valkaria', 'Q2154617', [[6, 7, 8]]],
#  ['alliance airport', 'Q5472378', [[12, 13]]],
#  ['fort worth, texas', 'Q16558', [[15, 16, 17, 18]]],
#  ['los maitenes airport', 'Q16899238', [[1, 2, 3]]],
#  ['retiro', 'Q56122', [[0], [12]]],
#  ['cecil county airport', 'Q19574884', [[6, 7, 8]]],
#  ['elkton, maryland', 'Q754338', [[16, 17, 18]]],
#  ['göteborg city airport', 'Q844281', [[16, 17, 18]]],
#  ['gothenburg', 'Q25287', [[3]]],
#  ['david jay perry airport', 'Q1709203', [[0, 1, 2, 3]]],
#  ['goldsby', 'Q2456775', [[14]]],
#  ['max westheimer airport', 'Q10853586', [[6, 7, 8]]],
#  ['norman', 'Q40347', [[10]]],
#  ['savitri jindal airport', 'Q18355676', [[6, 7, 8]]],
#  ['angul', 'Q518237', [[10]]],
#  ['airport', 'Q1571015', [[15]]],
#  ['regina, saskatchewan', 'Q2123', [[9, 10, 11]]],
#  ['dulles', 'Q466835', [[6]]],
#  ['washington', 'Q61', [[5]]],
#  ['orly airport', 'Q223416', [[18, 19]]],
#  ['paris', 'Q90', [[21]]],
#  ['ferdinand lumban tobing airport', 'Q4272430', [[1, 2, 3, 4]]],
#  ['sibolga', 'Q5984', [[21]]],
#  ['franco bianco airport', 'Q16891421', [[0, 1, 2]]],
#  ['cerro sombrero', 'Q1006493', [[8, 9]]],
#  ['hewanorra international airport', 'Q1431475', [[30, 31, 32]]],
#  ['vieux fort', 'Q1472864', [[7, 8]]],
#  ['anderson field', 'Q4754070', [[12, 13]]],
#  ['brewster', 'Q1506880', [[2]]],
#  ['khorog airport', 'Q6402378', [[0, 1]]],
#  ['khorugh', 'Q467501', [[6]]],
#  ['hongqiao airport', 'Q421811', [[18, 19]]],
#  ['shanghai', 'Q8686', [[4]]],
#  ['pinal airpark', 'Q5353435', [[0, 1]]],
#  ['marana', 'Q762743', [[6]]],
#  ['canefield airport', 'Q1033097', [[4, 5]]],
#  ['roseau', 'Q36281', [[0]]],
#  ['mercedita airport', 'Q652578', [[20, 21]]],
#  ['ponce', 'Q864024', [[23]]],
#  ['avelino vieira airport', 'Q4784231', [[0, 1, 2]]],
#  ['arapoti', 'Q1805391', [[7]]],
#  ['kvll - oakland/troy airport', 'Q2902372', [[14, 15, 16, 17, 18, 19]]],
#  ['troy, michigan', 'Q990271', [[21, 22, 23]]],
#  ['dalton airport', 'Q5211664', [[0, 1]]],
#  ['flushing', 'Q967748', [[8]]],
#  ['chattanooga metropolitan airport', 'Q1708272', [[0, 1, 2]]],
#  ['chattanooga, tennessee', 'Q186702', [[18, 19, 20]]],
#  ['fulton county airport', 'Q3274683', [[1, 2, 3]]],
#  ['atlanta', 'Q23556', [[23]]],
#  ['main airport', 'Q32999', [[11, 12]]],
#  ['vienna', 'Q1741', [[9]]],
#  ['rendani airport', 'Q964835', [[17, 18]]],
#  ['manokwari', 'Q848672', [[20]]],
#  ['bishop airport', 'Q4087670', [[22, 23]]],
#  ['bishop, california', 'Q852658', [[25, 26, 27]]],
#  ['tafraoui airfield', 'Q6588435', [[7, 8]]],
#  ['oran', 'Q131818', [[10]]],
#  ['ishasha river camp airport', 'Q21974285', [[16, 17, 18, 19]]],
#  ['queen elizabeth national park', 'Q530084', [[25, 26, 27, 28]]],
#  ['wakulla county airport', 'Q5309352', [[1, 2, 3]]],
#  ['panacea', 'Q5306283', [[11]]],
#  ['alberto carnevalli airport', 'Q2704391', [[26, 27, 28]]],
#  ['mérida', 'Q23551', [[0]]],
#  ['sadiq abubakar iii international airport',
#   'Q922675',
#   [[9, 10, 11, 12, 13]]],
#  ['sokoto', 'Q336350', [[15]]],
#  ['santa bárbara airport', 'Q16896455', [[0, 1, 2]]],
#  ['romeral', 'Q56124', [[11]]],
#  ['simisini air base', 'Q21974331', [[1, 2, 3]]],
#  ['kisangani', 'Q146723', [[0], [12]]],
#  ['aurel vlaicu international airport', 'Q843229', [[7, 8, 9, 10]]],
#  ['bucharest', 'Q19660', [[12]]],
#  ['gautam buddha airport', 'Q3275873', [[0, 1, 2]]],
#  ['siddharthanagar', 'Q1530936', [[5]]],
#  ['steve edwards field', 'Q14681184', [[9, 10, 11]]],
#  ['marianna', 'Q79582', [[0]]],
#  ['north texas regional airport', 'Q7056982', [[10, 11, 12, 13]]],
#  ['sherman', 'Q982379', [[15]]],
#  ['airport', 'Q654636', [[26]]],
#  ['larnaca', 'Q171882', [[21]]],
#  ['fukushima airport', 'Q177473', [[0, 1]]],
#  ['sukagawa', 'Q819664', [[3]]],
#  ['williams field', 'Q2748837', [[3, 4]]],
#  ['mcmurdo station', 'Q498627', [[20, 21]]],
#  ['northeast philadelphia airport', 'Q2739991', [[13, 14, 15]]],
#  ['philadelphia, pennsylvania', 'Q1345', [[17, 18, 19]]],
#  ['shj', 'Q635826', [[2]]],
#  ['sharjah', 'Q289693', [[0]]],
#  ['williamson county regional airport', 'Q8021210', [[10, 11, 12, 13]]],
#  ['marion', 'Q575399', [[20]]],
#  ['airport', 'Q17430', [[1]]],
#  ['saint-denis', 'Q47045', [[3, 4, 5]]],
#  ['mcginness airport', 'Q19876918', [[0, 1]]],
#  ['columbia', 'Q1133892', [[21]]],
#  ['marshall memorial municipal airport', 'Q14704430', [[9, 10, 11, 12]]],
#  ['marshall, missouri', 'Q954882', [[14, 15, 16]]],
#  ['sania ramel airport', 'Q1433058', [[10, 11, 12]]],
#  ['tetouan', 'Q185157', [[8]]],
#  ['agostinho neto airport', 'Q636824', [[18, 19, 20]]],
#  ['ponta do sol', 'Q768314', [[6, 7, 8]]],
#  ['frans kaisiepo international airport', 'Q2134812', [[0, 1, 2, 3]]],
#  ['biak', 'Q855314', [[11]]],
#  ['kish international airport', 'Q2670526', [[1, 2, 3]]],
#  ['kish island', 'Q221883', [[19, 20]]],
#  ['cheongju international airport', 'Q483675', [[0, 1, 2]]],
#  ['cheongwon-gu', 'Q42147', [[23, 24, 25]]],
#  ['king abdulaziz international airport', 'Q153592', [[12, 13, 14, 15]]],
#  ['jeddah', 'Q374365', [[17]]],
#  ['an airport', 'Q12694168', [[3, 4]]],
#  ['nicoya', 'Q2486629', [[0]]],
#  ['sheikh-ul-alam international airport', 'Q2247528', [[0, 1, 2, 3, 4, 5, 6]]],
#  ['srinagar', 'Q170115', [[8]]],
#  ['bugungu airstrip', 'Q21974272', [[0, 1]]],
#  ['murchison falls national park', 'Q1893242', [[12, 13, 14, 15]]],
#  ['atlantic municipal airport', 'Q2902476', [[19, 20, 21]]],
#  ['atlantic, iowa', 'Q756267', [[13, 14, 15]]],
#  ['edtl', 'Q597321', [[11]]],
#  ['lahr', 'Q7039', [[3], [25]]],
#  ['airport', 'Q7404650', [[14]]],
#  ['salinas', 'Q488125', [[9]]],
#  ['gustaf iii airport', 'Q38805', [[5, 6, 7]]],
#  ['saint barthélemy', 'Q25362', [[17, 18]]],
#  ['tempuling airport', 'Q18821722', [[0, 1]]],
#  ['tembilahan', 'Q6542770', [[10]]],
#  ['shuangliu airport', 'Q387560', [[1, 2]]],
#  ['chengdu', 'Q30002', [[4]]],
#  ['cam ranh', 'Q25226', [[7, 8]]],
#  ['nha trang', 'Q19491', [[11, 12]]],
#  ['bole international airport', 'Q44923', [[6, 7, 8]]],
#  ['addis ababa', 'Q3624', [[10, 11]]],
#  ['airport', 'Q631430', [[30]]],
#  ['kangerlussuaq', 'Q1007098', [[0]]],
#  ['oer', 'Q2673175', [[15]]],
#  ['örnsköldsvik', 'Q28327', [[11]]],
#  ['lsma', 'Q1934947', [[7]]],
#  ['alpnach', 'Q69296', [[3], [18]]],
#  ['shah makhdum airport', 'Q2875736', [[0, 1, 2]]],
#  ['rajshahi', 'Q322155', [[4]]],
#  ['juanda international airport', 'Q1431631', [[12, 13, 14]]],
#  ['surabaya', 'Q11462', [[10]]],
#  ['kctb', 'Q1655488', [[2]]],
#  ['cut bank, montana', 'Q968158', [[6, 7, 8, 9]]],
#  ['surkhet airport', 'Q1756900', [[0, 1]]],
#  ['birendranagar', 'Q865146', [[3]]],
#  ['airport', 'Q265994', [[8]]],
#  ['nuremberg', 'Q2090', [[13]]],
#  ['ivato international airport', 'Q670038', [[6, 7, 8]]],
#  ['antananarivo', 'Q3915', [[12]]],
#  ['keshod airport', 'Q2722850', [[0, 1]]],
#  ['junagadh', 'Q11864', [[9]]],
#  ['molco airport', 'Q16895275', [[4, 5]]],
#  ['choshuenco', 'Q5105354', [[0]]],
#  ['enshi xujiaping airport', 'Q1937966', [[0, 1, 2]]],
#  ['enshi city', 'Q1028110', [[9, 10]]],
#  ['arturo michelena international airport', 'Q2231898', [[11, 12, 13, 14]]],
#  ['valencia', 'Q54880', [[16]]],
#  ['wgp', 'Q652704', [[13]]],
#  ['waingapu', 'Q781361', [[3], [22]]],
#  ['linden airport', 'Q10853379', [[0, 1]]],
#  ['linden, new jersey', 'Q1004712', [[11, 12, 13, 14]]],
#  ['youngstown–warren regional airport', 'Q8058655', [[8, 9, 10, 11, 12]]],
#  ['youngstown, ohio', 'Q216820', [[14, 15, 16]]],
#  ['largest international airport', 'Q45938', [[19, 20, 21]]],
#  ['auckland', 'Q37100', [[0]]],
#  ['soko airport', 'Q7555134', [[5, 6]]],
#  ['bondoukou', 'Q892276', [[0]]],
#  ['frankfurt airport', 'Q46033', [[0, 1]]],
#  ['frankfurt am main', 'Q1794', [[16, 17, 18]]],
#  ['capodichino airport', 'Q849383', [[5, 6]]],
#  ['naples', 'Q2634', [[8]]],
#  ['hanover county municipal airport', 'Q3884853', [[0, 1, 2, 3]]],
#  ['richmond', 'Q43421', [[23]]],
#  ['dyersburg municipal airport', 'Q5318578', [[12, 13, 14]]],
#  ['dyersburg, tennessee', 'Q1268670', [[16, 17, 18]]],
#  ['wyandot county airport', 'Q24061424', [[0, 1, 2]]],
#  ['upper sandusky', 'Q1913338', [[17, 18]]],
#  ['julius nyerere international airport', 'Q1411192', [[17, 18, 19, 20]]],
#  ['dar es salaam', 'Q1960', [[22, 23, 24]]],
#  ['avenger field', 'Q2901599', [[0, 1]]],
#  ['city of sweetwater', 'Q981845', [[15, 16, 17]]],
#  ['rickenbacker international airport', 'Q1432595', [[23, 24, 25]]],
#  ['columbus', 'Q16567', [[33]]],
#  ['sbih', 'Q2902444', [[21]]],
#  ['itaituba', 'Q655734', [[13]]],
#  ['los rodeos airport', 'Q932514', [[15, 16, 17]]],
#  ['tenerife', 'Q40846', [[19]]],
#  ['lake cumberland regional airport', 'Q10853391', [[0, 1, 2, 3]]],
#  ['somerset', 'Q2303714', [[15]]],
#  ['isla grande airport', 'Q5444795', [[18, 19, 20]]],
#  ['san juan', 'Q41211', [[6, 7]]],
#  ['mountain valley airport', 'Q3886257', [[15, 16, 17]]],
#  ['tehachapi, california', 'Q985253', [[19, 20, 21]]],
#  ['virginia highlands airport', 'Q7934312', [[12, 13, 14]]],
#  ['abingdon', 'Q137919', [[20]]],
#  ['boudghene ben ali lotfi airport', 'Q2875808', [[5, 6, 7, 8, 9]]],
#  ['béchar', 'Q638704', [[3]]],
#  ['airport', 'Q2875819', [[6]]],
#  ['debre marqos', 'Q1024659', [[0, 1]]],
#  ['germán olano airport', 'Q1323338', [[4, 5, 6]]],
#  ['puerto carreño', 'Q130304', [[7, 8]]],
#  ['caucayá airport', 'Q1962669', [[5, 6]]],
#  ['puerto leguízamo', 'Q1525407', [[0, 1]]],
#  ['brunswick executive airport', 'Q3886398', [[14, 15, 16]]],
#  ['brunswick, maine', 'Q518466', [[18, 19, 20]]],
#  ['zamboanga international airport', 'Q1200033', [[29, 30, 31]]],
#  ['zamboanga city', 'Q1629', [[7, 8]]],
#  ['carti airstrip', 'Q19460881', [[16, 17]]],
#  ['cartí sugtupu', 'Q636822', [[0, 1]]],
#  ['yellowknife airport', 'Q2724008', [[5, 6]]],
#  ['yellowknife, northwest territories', 'Q2061', [[8, 9, 10, 11]]],
#  ['tallman east airport', 'Q7680162', [[0, 1, 2]]],
#  ['tower city, pennsylvania', 'Q1187340', [[8, 9, 10, 11]]],
#  ['erik nielsen whitehorse international airport',
#   'Q1433251',
#   [[8, 9, 10, 11, 12]]],
#  ['whitehorse, yukon', 'Q2058', [[14, 15, 16]]],
#  ['sahnewal airport', 'Q7399709', [[18, 19]]],
#  ['ludhiana', 'Q200123', [[21]]],
#  ['tunoshna airport', 'Q1147420', [[9, 10]]],
#  ['yaroslavl', 'Q2423', [[12]]],
#  ['commodore decatur airport', 'Q5153221', [[0, 1, 2]]],
#  ['bainbridge, georgia', 'Q788794', [[14, 15, 16]]],
#  ['la florida airport', 'Q1977854', [[0, 1, 2]]],
#  ['tumaco', 'Q1005555', [[4]]],
#  ['avalon airport', 'Q17896', [[14, 15]]],
#  ['geelong', 'Q231765', [[27]]],
#  ['grider field', 'Q5608629', [[28, 29]]],
#  ['pine bluff', 'Q80012', [[31, 32]]],
#  ['moyne aerodrome', 'Q3886239', [[0, 1]]],
#  ['thurles', 'Q383188', [[9]]],
#  ['senai international airport', 'Q3239110', [[12, 13, 14]]],
#  ['johor', 'Q183032', [[16]]],
#  ['international airport', 'Q1430826', [[3, 4]]],
#  ['aktau', 'Q198989', [[0]]],
#  ['lkvo', 'Q3487271', [[0]]],
#  ['prague', 'Q1085', [[12]]],
#  ['northwest regional airport', 'Q7060183', [[6, 7, 8]]],
#  ['roanoke, texas', 'Q969223', [[10, 11, 12]]],
#  ['scottsdale airport', 'Q17567', [[18, 19]]],
#  ['scottsdale, arizona', 'Q49221', [[21, 22, 23]]],
#  ['jefferson county international airport', 'Q2902617', [[10, 11, 12, 13]]],
#  ['port townsend, washington', 'Q1001828', [[15, 16, 17, 18]]],
#  ['batajnica air base', 'Q948600', [[5, 6, 7]]],
#  ['belgrade', 'Q3711', [[9]]],
#  ['bolton field', 'Q3886801', [[5, 6]]],
#  ['columbus', 'Q16567', [[15]]],
#  ['quatro de fevereiro airport', 'Q598002', [[7, 8, 9, 10]]],
#  ['luanda', 'Q3897', [[5]]],
#  ['ben gurion airport', 'Q181479', [[16, 17, 18]]],
#  ['tel aviv', 'Q33935', [[13, 14]]],
#  ['sheremetyevo international airport', 'Q192733', [[25, 26, 27]]],
#  ['moscow', 'Q649', [[29]]],
#  ['perry county airport', 'Q7169748', [[5, 6, 7]]],
#  ['linden', 'Q2607529', [[9]]],
#  ['lynden pindling international airport', 'Q1415006', [[18, 19, 20, 21]]],
#  ['nassau', 'Q2467', [[23]]],
#  ['gabreski airport', 'Q5482369', [[23, 24]]],
#  ['westhampton beach', 'Q3453197', [[26, 27]]],
#  ['del rio international airport', 'Q1657383', [[11, 12, 13, 14]]],
#  ['del rio, texas', 'Q970792', [[16, 17, 18, 19]]],
#  ['la aurora international airport', 'Q765608', [[15, 16, 17, 18]]],
#  ['guatemala city', 'Q1555', [[20, 21]]],
#  ['ukww', 'Q4111595', [[10]]],
#  ['vinnytsia', 'Q157144', [[15]]],
#  ['false river regional airport', 'Q5432665', [[17, 18, 19, 20]]],
#  ['new roads', 'Q2276773', [[9, 10]]],
#  ['bach mai airfield', 'Q2886528', [[25, 26, 27]]],
#  ['hanoi', 'Q1858', [[13]]],
#  ['shenandoah valley regional airport', 'Q7494187', [[0, 1, 2, 3]]],
#  ['staunton', 'Q502250', [[14]]],
#  ['airport', 'Q3503051', [[16]]],
#  ['long banga', 'Q6672234', [[4, 5]]],
#  ['airport', 'Q12692021', [[6]]],
#  ['breiðdalsvík', 'Q2924383', [[12]]],
#  ['north melbourne station', 'Q7056082', [[15, 16, 17]]],
#  ['west melbourne', 'Q12010545', [[12, 13]]],
#  ['fertilia airport', 'Q1321390', [[27, 28]]],
#  ['alghero', 'Q166282', [[14], [33]]],
#  ['international airport', 'Q1148527', [[4, 5]]],
#  ['ashgabat', 'Q23438', [[0]]],
#  ['matecaña international airport', 'Q381688', [[8, 9, 10]]],
#  ['pereira', 'Q51111', [[12]]],
#  ['paf base shahbaz', 'Q3694521', [[19, 20, 21]]],
#  ['jacobabad', 'Q1017696', [[23]]],
#  ['waalhaven', 'Q2262149', [[7]]],
#  ['rotterdam', 'Q34370', [[10]]],
#  ['egsh', 'Q349673', [[8]]],
#  ['norwich', 'Q130191', [[6]]],
#  ['kuwait international airport', 'Q527157', [[10, 11, 12]]],
#  ['kuwait city', 'Q35178', [[0, 1]]],
#  ['santa monica airport', 'Q7419789', [[18, 19, 20]]],
#  ['southern california', 'Q844837', [[22, 23]]],
#  ['santiago vila airport', 'Q5242807', [[0, 1, 2]]],
#  ['girardot', 'Q186193', [[9]]],
#  ['kellogg aaf', 'Q7945760', [[15, 16]]],
#  ['battle creek, michigan', 'Q810998', [[19, 20, 21, 22]]],
#  ['bykovo airport', 'Q1432096', [[17, 18]]],
#  ['moscow', 'Q649', [[7]]],
#  ['ugolny airport', 'Q1843329', [[9, 10]]],
#  ['anadyr', 'Q7978', [[12]]],
#  ['knox county regional airport', 'Q6423552', [[27, 28, 29, 30]]],
#  ['rockland', 'Q2078053', [[21]]],
#  ['depati amir airport', 'Q1530683', [[7, 8, 9]]],
#  ['pangkal pinang', 'Q8179', [[11, 12]]],
#  ['carlos manuel de céspedes airport', 'Q3536540', [[0, 1, 2, 3, 4]]],
#  ['bayamo', 'Q115382', [[13]]],
#  ['the airport', 'Q532778', [[21, 22]]],
#  ['dushanbe', 'Q9365', [[8], [24]]],
#  ['halim perdanakusuma airbase', 'Q1032934', [[9, 10, 11]]],
#  ['jakarta', 'Q3630', [[13]]],
#  ['gino lisa airport', 'Q1431308', [[4, 5, 6]]],
#  ['foggia', 'Q13464', [[8]]],
#  ['los cerrillos airport', 'Q5659235', [[4, 5, 6]]],
#  ['santiago', 'Q2887', [[8]]],
#  ['santa maria airport', 'Q1432755', [[15, 16, 17]]],
#  ['vila do porto', 'Q1003164', [[21, 22, 23]]],
#  ['toussaint louverture international airport', 'Q794560', [[8, 9, 10, 11]]],
#  ['port-au-prince', 'Q34261', [[13, 14, 15, 16, 17]]],
#  ['red lion airport', 'Q7304523', [[29, 30, 31]]],
#  ['vincentown', 'Q7932185', [[15]]],
#  ['halfpenny green airport', 'Q3915261', [[4, 5, 6]]],
#  ['wolverhampton', 'Q126269', [[11]]],
#  ['savannah airstrip', 'Q17108392', [[9, 10]]],
#  ['kihihi', 'Q6406018', [[12]]],
#  ['caiari airport', 'Q3813497', [[0, 1]]],
#  ['porto velho', 'Q172512', [[7, 8]]],
#  ['newport news/williamsburg international airport',
#   'Q6586790',
#   [[9, 10, 11, 12, 13, 14]]],
#  ['virginia peninsula', 'Q2553780', [[5, 6]]],
#  ['moorabbin airport', 'Q1232433', [[12, 13]]],
#  ['melbourne', 'Q3141', [[15]]],
#  ['surigao airport', 'Q7646281', [[9, 10]]],
#  ['surigao city', 'Q1019949', [[12, 13]]],
#  ['pierre elliott trudeau international airport',
#   'Q736627',
#   [[19, 20, 21, 22, 23]]],
#  ['montreal', 'Q340', [[18]]],
#  ['ontario international airport', 'Q949831', [[22, 23, 24]]],
#  ['ontario, california', 'Q488134', [[26, 27, 28]]],
#  ['raaf williamtown', 'Q17570', [[0, 1]]],
#  ['hunter region', 'Q1638164', [[27, 28]]],
#  ['"amerigo vespucci" airport', 'Q707731', [[2, 3, 4, 5, 6]]],
#  ['florence', 'Q2044', [[0]]],
#  ['sanga-sanga airport', 'Q1321647', [[0, 1, 2, 3]]],
#  ['bongao', 'Q155195', [[18]]],
#  ['sir seretse khama international airport',
#   'Q1327949',
#   [[12, 13, 14, 15, 16]]],
#  ['gaborone', 'Q3919', [[20]]],
#  ['châlons vatry airport', 'Q1837108', [[0, 1, 2]]],
#  ['châlons-en-champagne', 'Q47135', [[9, 10, 11, 12, 13]]],
#  ['villa independencia airport', 'Q25037266', [[0, 1, 2]]],
#  ['fray bentos', 'Q849835', [[4, 5]]],
#  ['chabeuil airport', 'Q2875976', [[9, 10]]],
#  ['valence', 'Q8848', [[7]]],
#  ['jardines del rey airport', 'Q2895532', [[0, 1, 2, 3]]],
#  ['cayo coco', 'Q1052012', [[11, 12]]],
#  ['heart of georgia regional airport', 'Q14686649', [[1, 2, 3, 4, 5]]],
#  ['eastman', 'Q1278280', [[12]]],
#  ['macon county airport', 'Q6724853', [[0, 1, 2]]],
#  ['macon county, north carolina', 'Q507575', [[9, 10, 11, 12, 13]]],
#  ['iwd', 'Q3274027', [[13]]],
#  ['ironwood', 'Q2002936', [[17]]],
#  ['bajpe airport', 'Q290527', [[6, 7]]],
#  ['mangalore', 'Q127041', [[4]]],
#  ['state library station', 'Q29026643', [[0, 1, 2]]],
#  ['melbourne cbd', 'Q6811747', [[19, 20]]],
#  ['south bend international airport', 'Q7566309', [[0, 1, 2, 3]]],
#  ['south bend, indiana', 'Q486877', [[5, 6, 7, 8]]],
#  ['douglas–charles airport', 'Q652545', [[25, 26, 27, 28]]],
#  ['roseau', 'Q36281', [[0]]],
#  ['mcnary field', 'Q649827', [[9, 10]]],
#  ['salem', 'Q43919', [[12]]],
#  ['adisumarmo airport', 'Q283970', [[9, 10]]],
#  ['surakarta', 'Q4803', [[12]]],
#  ['renner field', 'Q3914081', [[4, 5]]],
#  ['goodland', 'Q1931362', [[0], [12]]],
#  ['josé celestino mutis airport', 'Q2902785', [[0, 1, 2, 3]]],
#  ['bahía solano', 'Q1579457', [[10, 11]]],
#  ['labo airport', 'Q6467125', [[2, 3]]],
#  ['ozamiz', 'Q263837', [[0]]],
#  ['prestwick airport', 'Q8992', [[16, 17]]],
#  ['glasgow', 'Q4093', [[7]]],
#  ['velana international airport', 'Q29104', [[19, 20, 21]]],
#  ['malé', 'Q9347', [[23]]],
#  ['owen roberts international airport', 'Q665948', [[0, 1, 2, 3]]],
#  ['grand cayman', 'Q737765', [[9, 10]]],
#  ['forquilhinha airport', 'Q959295', [[3, 4]]],
#  ['criciúma', 'Q1439157', [[9]]],
#  ['felts field', 'Q5442691', [[0, 1]]],
#  ['spokane, washington', 'Q187805', [[7, 8, 9]]],
#  ['diego aracena international airport', 'Q1431221', [[0, 1, 2, 3]]],
#  ['iquique', 'Q14440', [[10]]],
#  ['tolmachevo airport', 'Q1328849', [[6, 7]]],
#  ['novosibirsk', 'Q883', [[4]]],
#  ['los perales airport', 'Q25037254', [[0, 1, 2]]],
#  ['bahía de caráquez', 'Q2749246', [[10, 11, 12]]],
#  ['former airport', 'Q2876065', [[21, 22]]],
#  ['santo domingo', 'Q34820', [[18, 19]]],
#  ['airport', 'Q44553', [[10]]],
#  ['benina', 'Q4888033', [[12]]],
#  ['wallblake airport', 'Q1657604', [[18, 19]]],
#  ['the valley', 'Q30994', [[4, 5]]],
#  ['international airport', 'Q1432651', [[5, 6]]],
#  ['rzeszów', 'Q598', [[0]]],
#  ['morristown regional airport', 'Q3612341', [[19, 20, 21]]],
#  ['morristown, tennessee', 'Q2330995', [[14, 15, 16]]],
#  ['mohammed v international airport', 'Q955433', [[5, 6, 7, 8]]],
#  ['casablanca', 'Q7903', [[4]]],
#  ['manhattan regional airport', 'Q4272488', [[0, 1, 2]]],
#  ['manhattan, kansas', 'Q856841', [[7, 8, 9]]],
#  ['josé maría córdova international airport',
#   'Q535161',
#   [[11, 12, 13, 14, 15]]],
#  ['medellín', 'Q48278', [[17]]],
#  ['mojave air and space port', 'Q390522', [[18, 19, 20, 21, 22]]],
#  ['mojave, california', 'Q1943133', [[24, 25, 26]]],
#  ['porto airport', 'Q943743', [[6, 7]]],
#  ['oporto', 'Q36433', [[15]]],
#  ['rdu', 'Q1192962', [[6]]],
#  ['raleigh', 'Q41087', [[0]]],
#  ['flamingo international airport', 'Q1430982', [[13, 14, 15]]],
#  ['bonaire', 'Q25396', [[21]]],
#  ['general manuel serrano airport', 'Q2374029', [[10, 11, 12, 13]]],
#  ['machala', 'Q215080', [[15]]],
#  ['villa reynolds airport', 'Q7930472', [[0, 1, 2]]],
#  ['villa mercedes', 'Q1756745', [[9, 10]]],
#  ['branson airport', 'Q1430977', [[20, 21]]],
#  ['branson, missouri', 'Q898857', [[23, 24, 25]]],
#  ['buma airfield', 'Q30542', [[7, 8]]],
#  ['kufra', 'Q172114', [[4]]],
#  ['ahmad yani international airport', 'Q1457975', [[0, 1, 2, 3]]],
#  ['semarang', 'Q11025', [[8]]],
#  ['gimhae international airport', 'Q483223', [[13, 14, 15]]],
#  ['busan', 'Q16520', [[17]]],
#  ['opis', 'Q1190316', [[12]]],
#  ['islamabad', 'Q1362', [[9]]],
#  ['la nubia airport', 'Q1936891', [[6, 7, 8]]],
#  ['manizales', 'Q235190', [[0]]],
#  ['former baiyun airport', 'Q5613723', [[25, 26, 27]]],
#  ['guangzhou', 'Q16572', [[18]]],
#  ['bandaranaike international airport', 'Q60900', [[19, 20, 21]]],
#  ['colombo', 'Q35381', [[6]]],
#  ['new chitose airport', 'Q908296', [[6, 7, 8]]],
#  ['sapporo', 'Q37951', [[10]]],
#  ['international airport', 'Q665365', [[3, 4]]],
#  ['bremen', 'Q24879', [[0]]],
#  ['darke county airport', 'Q1709059', [[3, 4, 5]]],
#  ['versailles', 'Q2538368', [[11]]],
#  ['melbourne international airport', 'Q652030', [[15, 16, 17]]],
#  ['melbourne, florida', 'Q949779', [[19, 20, 21]]],
#  ['phoenix goodyear airport', 'Q7186890', [[0, 1, 2]]],
#  ['phoenix, arizona', 'Q16556', [[23, 24, 25]]],
#  ['alcides fernández airport', 'Q1936968', [[0, 1, 2]]],
#  ['acandí', 'Q1575935', [[15]]],
#  ['columbus afb', 'Q1657653', [[14, 15]]],
#  ['columbus, mississippi', 'Q985648', [[17, 18, 19]]],
#  ['frans sales lega airport', 'Q12474050', [[0, 1, 2, 3]]],
#  ['ruteng', 'Q1708604', [[5], [12]]],
#  ['pattimura airport', 'Q2232506', [[0, 1]]],
#  ['ambon', 'Q18970', [[7]]],
#  ['el mirador airport', 'Q12692557', [[0, 1, 2]]],
#  ['puerto varas', 'Q51596', [[12, 13]]],
#  ['gansner field', 'Q3274627', [[0, 1]]],
#  ['quincy', 'Q1979185', [[9]]],
#  ['chennault international airport', 'Q1708583', [[10, 11, 12]]],
#  ['lake charles, louisiana', 'Q864106', [[5, 6, 7, 8]]],
#  ['cherif al idrissi airport', 'Q1370928', [[3, 4, 5, 6]]],
#  ['al hoceima', 'Q310350', [[0, 1]]],
#  ['air', 'Q17607', [[15]]],
#  ['bathurst island', 'Q810814', [[0, 1]]],
#  ['fatmawati soekarno airport', 'Q1880024', [[0, 1, 2]]],
#  ['bengkulu', 'Q8042', [[4]]],
#  ['la esperanza airport', 'Q16894649', [[0, 1, 2]]],
#  ['marchigüe', 'Q16921', [[11]]],
#  ['bindlacher berg airport', 'Q531596', [[0, 1, 2]]],
#  ['bayreuth', 'Q3923', [[7], [28]]],
#  ['gimpo airport', 'Q482493', [[11, 12]]],
#  ['seoul', 'Q8684', [[9]]],
#  ['el cardal airport', 'Q12692544', [[0, 1, 2]]],
#  ['río bueno', 'Q56126', [[11, 12]]],
#  ['enid woodring regional airport', 'Q5378895', [[14, 15, 16, 17]]],
#  ['enid, oklahoma', 'Q984361', [[0, 1, 2]]],
#  ['brighton city airport', 'Q735756', [[0, 1, 2]]],
#  ['west sussex', 'Q23287', [[20, 21]]],
#  ['nauru international airport', 'Q534251', [[8, 9, 10]]],
#  ['yaren district', 'Q31026', [[12, 13]]],
#  ['will rogers field', 'Q1499872', [[21, 22, 23]]],
#  ['oklahoma city', 'Q34863', [[25, 26]]],
#  ['ramenskoye airport', 'Q2388744', [[19, 20]]],
#  ['moscow', 'Q649', [[24]]],
#  ['mariscal sucre international airport', 'Q7376063', [[7, 8, 9, 10]]],
#  ['quito', 'Q2900', [[14]]],
#  ['wilson airport', 'Q1049288', [[15, 16]]],
#  ['nairobi', 'Q3870', [[18]]],
#  ['juhu aerodrome', 'Q674812', [[14, 15]]],
#  ['mumbai', 'Q1156', [[17]]],
#  ['brandon municipal airport', 'Q3502284', [[12, 13, 14]]],
#  ['brandon, manitoba', 'Q61432', [[16, 17, 18]]],
#  ['daugherty field', 'Q1431943', [[15, 16]]],
#  ['long beach', 'Q16739', [[9, 10]]],
#  ['le puy – loudes airport', 'Q2876024', [[8, 9, 10, 11, 12]]],
#  ['le puy-en-velay', 'Q184359', [[14, 15, 16, 17, 18, 19]]],
#  ['biggin hill', 'Q1431935', [[1, 2]]],
#  ['london', 'Q84', [[12]]],
#  ['sanganer airport', 'Q572387', [[3, 4]]],
#  ['jaipur', 'Q66485', [[6]]],
#  ['los pozos airport', 'Q28163860', [[0, 1, 2]]],
#  ['san gil', 'Q1294128', [[10, 11]]],
#  ['short airstrip', 'Q1653962', [[8, 9]]],
#  ['denis island', 'Q28920', [[0, 1]]],
#  ['jones field', 'Q2902318', [[5, 6]]],
#  ['bonham, texas', 'Q144856', [[8, 9, 10]]],
#  ['alférez fap alfredo vladimir sara bauer airport',
#   'Q4723923',
#   [[13, 14, 15, 16, 17, 18, 19]]],
#  ['andoas', 'Q3649471', [[21]]],
#  ['mokuti lodge airport', 'Q17090518', [[0, 1, 2]]],
#  ['etosha national park', 'Q675633', [[12, 13, 14]]],
#  ['meadows field airport', 'Q652265', [[9, 10, 11]]],
#  ['bakersfield', 'Q49256', [[7]]],
#  ['balmaceda airport', 'Q2901027', [[8, 9]]],
#  ['coyhaique', 'Q3810', [[13]]],
#  ['airport', 'Q1432275', [[4]]],
#  ['ouarzazate', 'Q505208', [[0]]],
#  ['yvr', 'Q321224', [[33]]],
#  ['vancouver', 'Q24639', [[26]]],
#  ['mahovljani', 'Q1430945', [[21]]],
#  ['banja luka', 'Q131127', [[14, 15]]],
#  ['ngari gunsa airport', 'Q1432172', [[0, 1, 2]]],
#  ['shiquanhe', 'Q2279283', [[8]]],
#  ['alula aba nega airport', 'Q4737322', [[5, 6, 7, 8]]],
#  ['mekelle', 'Q332319', [[3]]],
#  ['manas international airport', 'Q32997', [[21, 22, 23]]],
#  ['bishkek', 'Q9361', [[25]]],
#  ['hagerstown regional airport', 'Q3914582', [[9, 10, 11]]],
#  ['hagerstown, maryland', 'Q755559', [[13, 14, 15]]],
#  ['smolny (later rzhevka) airport', 'Q2383453', [[11, 12, 13, 14, 15, 16]]],
#  ['leningrad', 'Q656', [[18]]],
#  ['eloy alfaro international airport', 'Q1444671', [[1, 2, 3, 4]]],
#  ['manta', 'Q990738', [[6]]],
#  ['capital international airport', 'Q32190', [[17, 18, 19]]],
#  ['beijing', 'Q956', [[15]]],
#  ['juwata international airport', 'Q2233018', [[19, 20, 21]]],
#  ['tarakan', 'Q14501', [[23]]],
#  ['king mswati iii international airport', 'Q2285574', [[9, 10, 11, 12, 13]]],
#  ['manzini', 'Q495730', [[15]]],
#  ['sultan mahmud airport', 'Q2233067', [[4, 5, 6]]],
#  ['terengganu', 'Q189701', [[0]]],
#  ['international airport', 'Q123222', [[2, 3]]],
#  ['marsa alam', 'Q1001901', [[5, 6]]],
#  ['tit mellil airport', 'Q969543', [[1, 2, 3]]],
#  ['casablanca', 'Q7903', [[0], [18]]],
#  ['stuart powell field', 'Q7626968', [[0, 1, 2]]],
#  ['danville', 'Q988923', [[17]]],
#  ['sandra scabini airport', 'Q16898872', [[0, 1, 2]]],
#  ['punta arenas', 'Q51599', [[11, 12]]],
#  ['airport', 'Q12692416', [[4]]],
#  ['dekese', 'Q3021388', [[0]]],
#  ['linnahall', 'Q1810907', [[16]]],
#  ['tallinn', 'Q1770', [[18]]],
#  ['floyd bennett memorial airport', 'Q5462388', [[0, 1, 2, 3]]],
#  ['glens falls', 'Q1379621', [[29, 30]]],
#  ['zaventem airport', 'Q28934', [[22, 23]]],
#  ['brussels', 'Q240', [[20]]],
#  ['vanguardia airport', 'Q6465644', [[1, 2]]],
#  ['villavicencio', 'Q749224', [[10]]],
#  ['los angeles international airport', 'Q8731', [[0, 1, 2, 3]]],
#  ['greater los angeles area', 'Q1050826', [[27, 28, 29, 30]]],
#  ['seymour airport', 'Q1186422', [[11, 12]]],
#  ['baltra island', 'Q200772', [[6, 7]]],
#  ['yazoo county airport', 'Q8050637', [[0, 1, 2]]],
#  ['yazoo city', 'Q983832', [[8, 9]]],
#  ['bonriki international airport', 'Q522496', [[12, 13, 14]]],
#  ['south tarawa', 'Q131233', [[4, 5]]],
#  ['new international airport', 'Q18014849', [[9, 10, 11]]],
#  ['mexico city', 'Q1489', [[6, 7]]],
#  ['airport', 'Q1708732', [[2]]],
#  ['chifeng', 'Q570829', [[0]]],
#  ['turners falls airport', 'Q6588260', [[6, 7, 8]]],
#  ['montague', 'Q33180', [[10]]],
#  ['red lake airport', 'Q3912791', [[17, 18, 19]]],
#  ['red lake, ontario', 'Q1018643', [[9, 10, 11, 12]]],
#  ['ujae airport', 'Q4381230', [[0, 1]]],
#  ['ujae atoll', 'Q697802', [[10, 11]]],
#  ['le pontreau airport', 'Q2408589', [[1, 2, 3]]],
#  ['cholet', 'Q185066', [[0], [25]]],
#  ['an airport', 'Q1431605', [[13, 14]]],
#  ['jomsom', 'Q1702717', [[26]]],
#  ['bush airport–snyder field', 'Q3913448', [[11, 12, 13, 14, 15]]],
#  ['athens', 'Q755420', [[21]]],
#  ['henderson airfield', 'Q859876', [[16, 17]]],
#  ['honiara', 'Q40921', [[9]]],
#  ['svalbard airport, longyear', 'Q59633', [[29, 30, 31, 32]]],
#  ['longyearbyen', 'Q25923', [[27]]],
#  ['houssen airport', 'Q1431102', [[2, 3]]],
#  ['colmar', 'Q130994', [[0], [14]]],
#  ['isla picton airport', 'Q16892756', [[0, 1, 2]]],
#  ['quinta de tilcoco', 'Q56112', [[11, 12, 13]]],
#  ['wattay international airport', 'Q221279', [[13, 14, 15]]],
#  ['vientiane', 'Q9326', [[11]]],
#  ['luqa airport', 'Q672289', [[9, 10]]],
#  ['valletta', 'Q23800', [[19]]],
#  ['mbs international airport', 'Q652272', [[29, 30, 31]]],
#  ['saginaw', 'Q719', [[12]]],
#  ['ford airport', 'Q5467646', [[9, 10]]],
#  ['dearborn, michigan', 'Q430464', [[12, 13, 14]]],
#  ['clinton county airport', 'Q1655515', [[26, 27, 28]]],
#  ['plattsburgh', 'Q998669', [[6]]],
#  ['murtala muhammed international airport', 'Q1043631', [[0, 1, 2, 3]]],
#  ['ikeja', 'Q1024647', [[13]]],
#  ['pierrefonds airport', 'Q17431', [[0, 1]]],
#  ['saint-pierre', 'Q249884', [[12, 13, 14]]],
#  ['tulihal airport', 'Q2247550', [[0, 1]]],
#  ['imphal', 'Q208097', [[5]]],
#  ['general lucio blanco international airport',
#   'Q2232580',
#   [[9, 10, 11, 12, 13]]],
#  ['reynosa', 'Q738303', [[15]]],
#  ['niagara falls international airport', 'Q1984520', [[23, 24, 25, 26]]],
#  ['niagara falls, new york', 'Q128133', [[10, 11, 12, 13, 14]]],
#  ['mactan-cebu international airport', 'Q1048704', [[16, 17, 18, 19, 20]]],
#  ['metro cebu', 'Q1075343', [[26, 27]]],
#  ['rwj airpark', 'Q7278116', [[3, 4]]],
#  ['beach city', 'Q812835', [[17, 18]]],
#  ['china bay', 'Q7390732', [[21, 22]]],
#  ['trincomalee', 'Q323873', [[7], [24]]],
#  ['paramillo airport', 'Q5685452', [[0, 1]]],
#  ['san cristóbal', 'Q820235', [[6, 7]]],
#  ['kololo airstrip', 'Q10853684', [[12, 13]]],
#  ['kampala', 'Q3894', [[20]]],
#  ['rtm', 'Q656807', [[3]]],
#  ['rotterdam', 'Q34370', [[19]]],
#  ['abbotsford international airport', 'Q969671', [[9, 10, 11]]],
#  ['abbotsford, british columbia', 'Q271730', [[14, 15, 16, 17]]],
#  ['qiemo yudu airport', 'Q28127825', [[4, 5, 6]]],
#  ['qiemo town', 'Q3360588', [[19, 20]]],
#  ['airport, opened in january 2017', 'Q28797312', [[5, 6, 7, 8, 9, 10]]],
#  ['ambrolauri', 'Q456842', [[0]]],
#  ['gustavo rizo airport', 'Q3646815', [[8, 9, 10]]],
#  ['baracoa', 'Q94775', [[12]]],
#  ['maio airport', 'Q2011846', [[27, 28]]],
#  ['cidade do maio', 'Q489776', [[6, 7, 8]]],
#  ['inca manco cápac international airport', 'Q1286295', [[0, 1, 2, 3, 4]]],
#  ['juliaca', 'Q696074', [[15]]],
#  ['swami vivekananda airport', 'Q1595087', [[8, 9, 10]]],
#  ['raipur', 'Q372773', [[12]]],
#  ['pochentong airport', 'Q1054163', [[19, 20]]],
#  ['phnom penh', 'Q1850', [[16, 17]]],
#  ['swan island municipal airport', 'Q16900962', [[1, 2, 3, 4]]],
#  ['portland, oregon', 'Q6106', [[20, 21, 22]]],
#  ['woja', 'Q8029103', [[26]]],
#  ['ailinglaplap atoll', 'Q405165', [[28, 29]]],
#  ['pegasus field', 'Q3374224', [[14, 15]]],
#  ['mcmurdo station', 'Q498627', [[1, 2]]],
#  ['harriman-and-west airport', 'Q3887968', [[16, 17, 18, 19, 20, 21]]],
#  ['north adams', 'Q49185', [[7, 8]]],
#  ['jean lesage airport', 'Q794549', [[17, 18, 19]]],
#  ['quebec city', 'Q2145', [[21, 22]]],
#  ['montichiari airport', 'Q1430989', [[13, 14]]],
#  ['brescia', 'Q6221', [[0], [25]]],
#  ...]

# %% [markdown]
# There appears to be one token for each word in the entitiy, not sure what the meaning is though
